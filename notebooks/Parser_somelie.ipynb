# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
url = 'https://www.somelie.ru/otzyvy/?section=794'
r = requests.get(url, headers={'User-Agent': 'my-app/0.0.1'})

# %%
def parse_table(table):#Функция разбора таблицы с вопросом
    
    res = pd.DataFrame()
    wine_name = ''
    username = ''
    wine_type = ''
    brand = ''
    wine_link = ''
    review_link = ''
    
    
    name_tr = table.find('b')
    if(name_tr!=None):
        wine_name = name_tr.text.strip()
    
    login_tr = table.find('small')
    if(login_tr!=None):
        username = login_tr.text.strip()
    
    score_tr = table.find('div',{'class': 'rating'}).find('a')
    if(score_tr!=None):
        rating = score_tr.text.strip()
    
    link = 'https://www.somelie.ru'
    wine_link_tr = table.find('a')
    if(score_tr!=None):
        wine_link = link + wine_link_tr.get('href')
        
    url = wine_link
    r = requests.get(url, headers={'User-Agent': 'my-app/0.0.1'})
    soup = BeautifulSoup(r.text)
    tables = soup.find_all('table', {'class': 'characteristics'})
    
    for item in tables:
        wine_type_tr = item.find('td')
        if(wine_type_tr!=None):
            wine_type = wine_type_tr.text
            break
            
    tables = soup.find('div', {'class' : 'subtitle'})
    if(tables!=None):
        brand = tables.text
    
    variants_number = 5
    time.sleep(3)
    res = res.append(pd.DataFrame([[wine_name, username, rating, variants_number, wine_type, brand, wine_link, review_link]], 
                            columns = ['wine_name','username','rating','variants_number', 'wine_type', 'brand', 
                                       'wine_link', 'review_link']), ignore_index=True)
    return res

# %%
result = pd.DataFrame()

r = requests.get(url)
soup = BeautifulSoup(r.text) #Отправляем полученную страницу в библиотеку для парсинга
table = soup.find_all('div', {'class': 'news-item'})

# %%
for item in table:
    res = parse_table(item)
    result = result.append(res, ignore_index=True)
result
# Out:
#                                             wine_name  \
# 0                       вино 12 ЛУНАС БЛАНКО 14% 0.75
# 1              вино ФАМИЛИЯ ПАЧЕКО РОСАДО 11-15% 0.75
# 2                               вино СЕРВИДОР 12% 1,0
# 3
# 4
# 5
# 6                        вино УРБЕ АУГУШТА 9-13% 0,75
# 7        вино ЭТУАЛЬ ДЕ ЛОДЮК МАЛЬБЕК 2018 13.5% 0,75
# 8                        вино ВИА ЛАТИНА 9.5-10% 0.75
# 9                        вино УРБЕ АУГУШТА 9-13% 0,75
# 10                       Зу! Совиньон блан 12.5% 0.75
# 11                    вино ЛА ФОРТЕЦЦА ГРЕКО 13% 0.75
# 12                       вино АМИКОНЕ 13.5-14.5% 0.75
# 13     вино игристое ФРАНКОРИАНИ СПУМАНТЕ 9-9,5% 0,75
# 14   Вино безалкогольное ВАН ЛОФЕРЕН ОЛМОСТ ЗЕРО 0.75
# 15  вино КАМПО МАРИН ГАРНАЧА ТЕМПРАНИЛЬО КАБЕРНЕ 1...
# 16   Вино безалкогольное ВАН ЛОФЕРЕН ОЛМОСТ ЗЕРО 0.75
# 17              вино АБАДИЯ ДА КОВА А ФУГА 12.5% 0.75
# 18         вино АБАДИЯ ДА КОВА МЕНСИЯ РОСАДО 13% 0.75
# 19              вино АБАДИЯ ДА КОВА А ФУГА 13.5% 0.75
#
#                                              username rating  variants_number  \
# 0    Наталья\t\t\t\t\t\t\t\t\t\t\t02.10.2020 09:21:15      4                5
# 1       Анна\t\t\t\t\t\t\t\t\t\t\t30.09.2020 22:25:05      1                5
# 2   inkomledi@yandex.ru\t\t\t\t\t\t\t\t\t\t\t30.09...      5                5
# 3   inkomledi@yandex.ru\t\t\t\t\t\t\t\t\t\t\t30.09...      5                5
# 4   inkomledi@yandex.ru\t\t\t\t\t\t\t\t\t\t\t30.09...      5                5
# 5   Екатерина\t\t\t\t\t\t\t\t\t\t\t30.09.2020 14:2...      5                5
# 6   golovanov-va@yandex.ru\t\t\t\t\t\t\t\t\t\t\t28...      5                5
# 7   elizaveta101@gmail.com\t\t\t\t\t\t\t\t\t\t\t27...                       5
# 8   busi-project@yandex.ru\t\t\t\t\t\t\t\t\t\t\t23...      5                5
# 9   vchechkanova@bk.ru\t\t\t\t\t\t\t\t\t\t\t23.09....                       5
# 10  aa_kk@mail.ru\t\t\t\t\t\t\t\t\t\t\t21.09.2020 ...      1                5
# 11   glinmax\t\t\t\t\t\t\t\t\t\t\t19.09.2020 14:44:54                       5
# 12   Сергей \t\t\t\t\t\t\t\t\t\t\t18.09.2020 17:59:23      5                5
# 13  vchechkanova@bk.ru\t\t\t\t\t\t\t\t\t\t\t18.09....                       5
# 14  alondrik11@mail.ru\t\t\t\t\t\t\t\t\t\t\t17.09....                       5
# 15     Mukti\t\t\t\t\t\t\t\t\t\t\t16.09.2020 21:45:14                       5
# 16  gud-alex@mail.ru\t\t\t\t\t\t\t\t\t\t\t15.09.20...                       5
# 17  dominat-svetlana@mail.ru\t\t\t\t\t\t\t\t\t\t\t...                       5
# 18  dominat-svetlana@mail.ru\t\t\t\t\t\t\t\t\t\t\t...                       5
# 19  dominat-svetlana@mail.ru\t\t\t\t\t\t\t\t\t\t\t...                       5
#
#               wine_type                                              brand  \
# 0            тихое вино                                    12 LUNAS BLANCO
# 1            тихое вино                             Familia Pacheco Rosado
# 2            тихое вино                                           Servidor
# 3            тихое вино                                           Servidor
# 4            тихое вино                                           Servidor
# 5            тихое вино                                           Servidor
# 6            тихое вино                                       Urbe Augusta
# 7            тихое вино                            Etoile de Lauduc Malbec
# 8            тихое вино                                    Via Latina Rose
# 9            тихое вино                                       Urbe Augusta
# 10           тихое вино                               ZU! SAUVIGNON BLANC
# 11           тихое вино                                  LA FORTEZZA GRECO
# 12           тихое вино                                            Amicone
# 13        игристое вино                               Francoriani Spumante
# 14  безалкогольное вино      VAN LOVEREN ALMOST ZERO DE-ALCOHOLISED WHITE
# 15           тихое вино  CAMPO MARIN GARNACHA TEMPRANILLO CABERNET Cari...
# 16  безалкогольное вино      VAN LOVEREN ALMOST ZERO DE-ALCOHOLISED WHITE
# 17           тихое вино                             ABADIA DA COVA A FUGA
# 18           тихое вино                       ABADIA DA COVA MENCIA ROSADO
# 19           тихое вино                             ABADIA DA COVA A FUGA
#
#                                             wine_link review_link
# 0   https://www.somelie.ru/products/vino_12_lunas_...
# 1   https://www.somelie.ru/products/vino_familiya_...
# 2   https://www.somelie.ru/products/vino-servidor-...
# 3   https://www.somelie.ru/products/vino-servidor-...
# 4   https://www.somelie.ru/products/vino-servidor-...
# 5   https://www.somelie.ru/products/vino-servidor-...
# 6   https://www.somelie.ru/products/vino_urbe_augu...
# 7   https://www.somelie.ru/products/vino_etual_de_...
# 8   https://www.somelie.ru/products/vino-via-latin...
# 9   https://www.somelie.ru/products/vino_urbe_augu...
# 10  https://www.somelie.ru/products/vino_zu_sovino...
# 11  https://www.somelie.ru/products/vino_la_fortet...
# 12  https://www.somelie.ru/products/vino-amikone-1...
# 13  https://www.somelie.ru/products/vino-igristoe-...
# 14  https://www.somelie.ru/products/vino_bezalkogo...
# 15  https://www.somelie.ru/products/vino_kampo_mar...
# 16  https://www.somelie.ru/products/vino_bezalkogo...
# 17  https://www.somelie.ru/products/vino_abadiya_d...
# 18  https://www.somelie.ru/products/vino_abadiya_d...
# 19  https://www.somelie.ru/products/vino_abadiya_d...

# %%
link = 'https://www.somelie.ru/otzyvy/?section=794&PAGEN_3='
for i in range (2, 50):
    url = link + str(i)
    r = requests.get(url, headers={'User-Agent': 'my-app/0.0.1'})
    soup = BeautifulSoup(r.text) 
    tables = soup.find_all('div', {'class': 'news-item'})
    for item in table:
        res = parse_table(item)
        result = result.append(res, ignore_index=True)

# %%
result = result.loc[0:4879, :]
result
# Out:
#                                               wine_name  \
# 0                         вино 12 ЛУНАС БЛАНКО 14% 0.75
# 1                вино ФАМИЛИЯ ПАЧЕКО РОСАДО 11-15% 0.75
# 2                                 вино СЕРВИДОР 12% 1,0
# 3
# 4
# ...                                                 ...
# 4875  вино КАМПО МАРИН ГАРНАЧА ТЕМПРАНИЛЬО КАБЕРНЕ 1...
# 4876   Вино безалкогольное ВАН ЛОФЕРЕН ОЛМОСТ ЗЕРО 0.75
# 4877              вино АБАДИЯ ДА КОВА А ФУГА 12.5% 0.75
# 4878         вино АБАДИЯ ДА КОВА МЕНСИЯ РОСАДО 13% 0.75
# 4879              вино АБАДИЯ ДА КОВА А ФУГА 13.5% 0.75
#
#                                                username rating  \
# 0      Наталья\t\t\t\t\t\t\t\t\t\t\t02.10.2020 09:21:15      4
# 1         Анна\t\t\t\t\t\t\t\t\t\t\t30.09.2020 22:25:05      1
# 2     inkomledi@yandex.ru\t\t\t\t\t\t\t\t\t\t\t30.09...      5
# 3     inkomledi@yandex.ru\t\t\t\t\t\t\t\t\t\t\t30.09...      5
# 4     inkomledi@yandex.ru\t\t\t\t\t\t\t\t\t\t\t30.09...      5
# ...                                                 ...    ...
# 4875     Mukti\t\t\t\t\t\t\t\t\t\t\t16.09.2020 21:45:14
# 4876  gud-alex@mail.ru\t\t\t\t\t\t\t\t\t\t\t15.09.20...
# 4877  dominat-svetlana@mail.ru\t\t\t\t\t\t\t\t\t\t\t...
# 4878  dominat-svetlana@mail.ru\t\t\t\t\t\t\t\t\t\t\t...
# 4879  dominat-svetlana@mail.ru\t\t\t\t\t\t\t\t\t\t\t...
#
#       variants_number            wine_type  \
# 0                   5           тихое вино
# 1                   5           тихое вино
# 2                   5           тихое вино
# 3                   5           тихое вино
# 4                   5           тихое вино
# ...               ...                  ...
# 4875                5           тихое вино
# 4876                5  безалкогольное вино
# 4877                5           тихое вино
# 4878                5           тихое вино
# 4879                5           тихое вино
#
#                                                   brand  \
# 0                                       12 LUNAS BLANCO
# 1                                Familia Pacheco Rosado
# 2                                              Servidor
# 3                                              Servidor
# 4                                              Servidor
# ...                                                 ...
# 4875  CAMPO MARIN GARNACHA TEMPRANILLO CABERNET Cari...
# 4876      VAN LOVEREN ALMOST ZERO DE-ALCOHOLISED WHITE
# 4877                             ABADIA DA COVA A FUGA
# 4878                       ABADIA DA COVA MENCIA ROSADO
# 4879                             ABADIA DA COVA A FUGA
#
#                                               wine_link review_link
# 0     https://www.somelie.ru/products/vino_12_lunas_...
# 1     https://www.somelie.ru/products/vino_familiya_...
# 2     https://www.somelie.ru/products/vino-servidor-...
# 3     https://www.somelie.ru/products/vino-servidor-...
# 4     https://www.somelie.ru/products/vino-servidor-...
# ...                                                 ...         ...
# 4875  https://www.somelie.ru/products/vino_kampo_mar...
# 4876  https://www.somelie.ru/products/vino_bezalkogo...
# 4877  https://www.somelie.ru/products/vino_abadiya_d...
# 4878  https://www.somelie.ru/products/vino_abadiya_d...
# 4879  https://www.somelie.ru/products/vino_abadiya_d...
#
# [4880 rows x 8 columns]

# %%
link = 'https://www.somelie.ru/otzyvy/?section=794&PAGEN_3='
for i in range (280, 294):
    url = link + str(i)
    r = requests.get(url, headers={'User-agent':'Mozilla/5.0','Referer':'http://www.python.org/'})
    soup = BeautifulSoup(r.text) 
    tables = soup.find_all('div', {'class': 'news-item'})
    for item in table:
        res = parse_table(item)
        result = result.append(res, ignore_index=True)
result
# Out:
#                                               wine_name  \
# 0                         вино 12 ЛУНАС БЛАНКО 14% 0.75
# 1                вино ФАМИЛИЯ ПАЧЕКО РОСАДО 11-15% 0.75
# 2                                 вино СЕРВИДОР 12% 1,0
# 3
# 4
# ...                                                 ...
# 5875  вино КАМПО МАРИН ГАРНАЧА ТЕМПРАНИЛЬО КАБЕРНЕ 1...
# 5876   Вино безалкогольное ВАН ЛОФЕРЕН ОЛМОСТ ЗЕРО 0.75
# 5877              вино АБАДИЯ ДА КОВА А ФУГА 12.5% 0.75
# 5878         вино АБАДИЯ ДА КОВА МЕНСИЯ РОСАДО 13% 0.75
# 5879              вино АБАДИЯ ДА КОВА А ФУГА 13.5% 0.75
#
#                                                username rating  \
# 0      Наталья\t\t\t\t\t\t\t\t\t\t\t02.10.2020 09:21:15      4
# 1         Анна\t\t\t\t\t\t\t\t\t\t\t30.09.2020 22:25:05      1
# 2     inkomledi@yandex.ru\t\t\t\t\t\t\t\t\t\t\t30.09...      5
# 3     inkomledi@yandex.ru\t\t\t\t\t\t\t\t\t\t\t30.09...      5
# 4     inkomledi@yandex.ru\t\t\t\t\t\t\t\t\t\t\t30.09...      5
# ...                                                 ...    ...
# 5875     Mukti\t\t\t\t\t\t\t\t\t\t\t16.09.2020 21:45:14
# 5876  gud-alex@mail.ru\t\t\t\t\t\t\t\t\t\t\t15.09.20...
# 5877  dominat-svetlana@mail.ru\t\t\t\t\t\t\t\t\t\t\t...
# 5878  dominat-svetlana@mail.ru\t\t\t\t\t\t\t\t\t\t\t...
# 5879  dominat-svetlana@mail.ru\t\t\t\t\t\t\t\t\t\t\t...
#
#       variants_number            wine_type  \
# 0                   5           тихое вино
# 1                   5           тихое вино
# 2                   5           тихое вино
# 3                   5           тихое вино
# 4                   5           тихое вино
# ...               ...                  ...
# 5875                5           тихое вино
# 5876                5  безалкогольное вино
# 5877                5           тихое вино
# 5878                5           тихое вино
# 5879                5           тихое вино
#
#                                                   brand  \
# 0                                       12 LUNAS BLANCO
# 1                                Familia Pacheco Rosado
# 2                                              Servidor
# 3                                              Servidor
# 4                                              Servidor
# ...                                                 ...
# 5875  CAMPO MARIN GARNACHA TEMPRANILLO CABERNET Cari...
# 5876      VAN LOVEREN ALMOST ZERO DE-ALCOHOLISED WHITE
# 5877                             ABADIA DA COVA A FUGA
# 5878                       ABADIA DA COVA MENCIA ROSADO
# 5879                             ABADIA DA COVA A FUGA
#
#                                               wine_link review_link
# 0     https://www.somelie.ru/products/vino_12_lunas_...
# 1     https://www.somelie.ru/products/vino_familiya_...
# 2     https://www.somelie.ru/products/vino-servidor-...
# 3     https://www.somelie.ru/products/vino-servidor-...
# 4     https://www.somelie.ru/products/vino-servidor-...
# ...                                                 ...         ...
# 5875  https://www.somelie.ru/products/vino_kampo_mar...
# 5876  https://www.somelie.ru/products/vino_bezalkogo...
# 5877  https://www.somelie.ru/products/vino_abadiya_d...
# 5878  https://www.somelie.ru/products/vino_abadiya_d...
# 5879  https://www.somelie.ru/products/vino_abadiya_d...
#
# [5880 rows x 8 columns]

# %%
result
# Out:
#                                    wine_name  \
# 0              вино 12 ЛУНАС БЛАНКО 14% 0.75
# 1     вино ФАМИЛИЯ ПАЧЕКО РОСАДО 11-15% 0.75
# 2                      вино СЕРВИДОР 12% 1,0
# 3
# 4
# ...                                      ...
# 4888            вино ВИА ЛАТИНА 9.5-10% 0.75
# 4889            вино УРБЕ АУГУШТА 9-13% 0,75
# 4890            Зу! Совиньон блан 12.5% 0.75
# 4891         вино ЛА ФОРТЕЦЦА ГРЕКО 13% 0.75
# 4892            вино АМИКОНЕ 13.5-14.5% 0.75
#
#                                                username rating  \
# 0      Наталья\t\t\t\t\t\t\t\t\t\t\t02.10.2020 09:21:15      4
# 1         Анна\t\t\t\t\t\t\t\t\t\t\t30.09.2020 22:25:05      1
# 2     inkomledi@yandex.ru\t\t\t\t\t\t\t\t\t\t\t30.09...      5
# 3     inkomledi@yandex.ru\t\t\t\t\t\t\t\t\t\t\t30.09...      5
# 4     inkomledi@yandex.ru\t\t\t\t\t\t\t\t\t\t\t30.09...      5
# ...                                                 ...    ...
# 4888  busi-project@yandex.ru\t\t\t\t\t\t\t\t\t\t\t23...      5
# 4889  vchechkanova@bk.ru\t\t\t\t\t\t\t\t\t\t\t23.09....
# 4890  aa_kk@mail.ru\t\t\t\t\t\t\t\t\t\t\t21.09.2020 ...      1
# 4891   glinmax\t\t\t\t\t\t\t\t\t\t\t19.09.2020 14:44:54
# 4892   Сергей \t\t\t\t\t\t\t\t\t\t\t18.09.2020 17:59:23      5
#
#       variants_number   wine_type                   brand  \
# 0                   5  тихое вино         12 LUNAS BLANCO
# 1                   5  тихое вино  Familia Pacheco Rosado
# 2                   5  тихое вино                Servidor
# 3                   5  тихое вино                Servidor
# 4                   5  тихое вино                Servidor
# ...               ...         ...                     ...
# 4888                5  тихое вино         Via Latina Rose
# 4889                5  тихое вино            Urbe Augusta
# 4890                5  тихое вино    ZU! SAUVIGNON BLANC
# 4891                5  тихое вино       LA FORTEZZA GRECO
# 4892                5  тихое вино                 Amicone
#
#                                               wine_link review_link
# 0     https://www.somelie.ru/products/vino_12_lunas_...
# 1     https://www.somelie.ru/products/vino_familiya_...
# 2     https://www.somelie.ru/products/vino-servidor-...
# 3     https://www.somelie.ru/products/vino-servidor-...
# 4     https://www.somelie.ru/products/vino-servidor-...
# ...                                                 ...         ...
# 4888  https://www.somelie.ru/products/vino-via-latin...
# 4889  https://www.somelie.ru/products/vino_urbe_augu...
# 4890  https://www.somelie.ru/products/vino_zu_sovino...
# 4891  https://www.somelie.ru/products/vino_la_fortet...
# 4892  https://www.somelie.ru/products/vino-amikone-1...
#
# [4893 rows x 8 columns]

# %%
result.to_csv('wine.csv')
# Out:
#   File "<ipython-input-2-6b74db391993>", line 1
#     result.to_csv('wine.csv')Z
#                              ^
# SyntaxError: invalid syntax

# %%
result = pd.read_csv('wine.csv')
